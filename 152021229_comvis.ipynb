# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import files
from IPython.display import Image, display
from PIL import Image, ImageEnhance
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from google.colab import files  # Hanya jika Anda menggunakan Google Colab

# Upload image file
uploaded = files.upload()

# Menampilkan informasi tentang berkas yang diunggah
for filename in uploaded.keys():
    print(f"Uploaded file '{filename}' with length {len(uploaded[filename])} bytes")
    pil_image = Image.open(filename)

# Plot the original image
plt.subplot(1, 3, 1)
plt.imshow(pil_image)
plt.title('Original Image')
plt.axis('off')

# Convert the PIL image to NumPy array
img_rgb = np.array(pil_image)

# Calculate histograms for each channel (Red, Green, Blue)
hist_r, bins_r = np.histogram(img_rgb[:, :, 0], bins=256, range=[0, 256])
hist_g, bins_g = np.histogram(img_rgb[:, :, 1], bins=256, range=[0, 256])
hist_b, bins_b = np.histogram(img_rgb[:, :, 2], bins=256, range=[0, 256])

# Plot histograms
plt.subplot(1, 3, 2)
plt.plot(hist_r, color='r', label='Red')
plt.plot(hist_g, color='g', label='Green')
plt.plot(hist_b, color='b', label='Blue')
plt.title("RGB Histogram")
plt.xlabel("Pixel Value")
plt.ylabel("Frequency")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-d2bef8d2-0421-4f94-a1ed-3fa66c57d0fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2bef8d2-0421-4f94-a1ed-3fa66c57d0fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import files
from IPython.display import Image, display
from PIL import Image, ImageEnhance

# Upload Image
uploaded = files.upload()

for filename in uploaded.keys():
    print(f"Uploaded file '{filename}' with length {len(uploaded[filename])} bytes")

    # Read the uploaded image using OpenCV
    img = cv2.imread(filename)

    if img is not None:
        # Split the image into its R, G, and B channels
        b_channel, g_channel, r_channel = cv2.split(img)

        # Calculate the histograms for each channel
        hist_r = cv2.calcHist([r_channel], [0], None, [256], [0, 256])
        hist_g = cv2.calcHist([g_channel], [0], None, [256], [0, 256])
        hist_b = cv2.calcHist([b_channel], [0], None, [256], [0, 256])

        # Plot the histograms
        plt.figure(figsize=(12, 4))

        plt.subplot(1, 4, 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title('Original Image')
        plt.axis('off')

        plt.subplot(1, 4, 2)
        plt.plot(hist_r, color='r', label='Red')
        plt.title("Red Channel Histogram")
        plt.xlabel("Pixel Value")
        plt.ylabel("Frequency")
        plt.legend()

        plt.subplot(1, 4, 3)
        plt.plot(hist_g, color='g', label='Green')
        plt.title("Green Channel Histogram")
        plt.xlabel("Pixel Value")
        plt.ylabel("Frequency")
        plt.legend()

        plt.subplot(1, 4, 4)
        plt.plot(hist_b, color='b', label='Blue')
        plt.title("Blue Channel Histogram")
        plt.xlabel("Pixel Value")
        plt.ylabel("Frequency")
        plt.legend()

        plt.tight_layout()
        plt.show()
# Out:
#      <input type="file" id="files-85b87720-b47c-4a16-905c-e5f70dc838be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85b87720-b47c-4a16-905c-e5f70dc838be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import files
from PIL import Image

# Upload Image
uploaded = files.upload()

for filename in uploaded.keys():
    print(f"Uploaded file '{filename}' with length {len(uploaded[filename])} bytes")

    # Convert the uploaded byte string into a numpy array
    image_data = np.frombuffer(uploaded[filename], np.uint8)

    # Read the image with OpenCV
    img = cv2.imdecode(image_data, cv2.IMREAD_COLOR)

    # Show the original image
    plt.subplot(1, 4, 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')

    # Create Color Histogram
    colors = ('b', 'g', 'r')

    for i, col in enumerate(colors):
        hist = cv2.calcHist([img], [i], None, [256], [0, 256])
        plt.subplot(1, 4, i + 2)
        plt.plot(hist, color=col)
        plt.xlim([0, 256])
        plt.title(f'{col.upper()} Channel Histogram')
        plt.xlabel('Pixel Value')
        plt.ylabel('Frequency')

    plt.tight_layout()
    plt.show()
# Out:
#      <input type="file" id="files-408d3280-218e-4dd5-a359-ad36d0f793a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-408d3280-218e-4dd5-a359-ad36d0f793a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
